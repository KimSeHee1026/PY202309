# %%
print("What do you call a bear with no teeth?" + "\n" + "A gummy bear!")
# Out:
# What do you call a bear with no teeth?
# A gummy bear!

# %%
name = input("Enter your name: ")
print("Hello "+name)
# Out:
# Enter your name: KimSeHee
# Hello KimSeHee

# %%
name = input("Enter your name: ")
last_name = input("Enter your name: "")
print("Hello" + name + last_name)
# Out:
# Enter your name: SeHee
# Enter your name: Kim
# Hello SeHeeKim

# %%
first_number = int(input("Enter the first number: "))
second_number = int(input("Enter the second number: "))
summit = first_number + second_number

print(frist_number, " + ",second_number, " = ", summit)
# Out:
# Enter the first number: 1
# Enter the second number: 4
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-23-096430f48fd0> in <module>
#       3 summit = first_number + second_number
#       4
# ----> 5 print(frist_number, " + ",second_number, " = ", summit)
#
# NameError: name 'frist_number' is not defined
