# %%
person_info = {}
person_info["Jenny"] = {"phone":"123-456-7890", "email":"jenny@jnu.ac.kr"}
person_info["Bob"] = {"phone":"555-666-7777", "email":"rice@jnu.c.kr"}
person_info["David"] = {"phone":"999-000-999", "email":"dvd@jnu.ac.kr"}

name_list = list(person_info.keys())

print("Name: ", name_list[0], " / info: ", *list(person_info[name_list[0]].items()))
print("Name: ", name_list[1], " / info: ", *list(person_info[name_list[1]].items()))
print("Name: ", name_list[2], " / info: ", *list(person_info[name_list[2]].items()))
# Out:
# Name:  Jenny  / info:  ('phone', '123-456-7890') ('email', 'jenny@jnu.ac.kr')
# Name:  Bob  / info:  ('phone', '555-666-7777') ('email', 'rice@jnu.c.kr')
# Name:  David  / info:  ('phone', '999-000-999') ('email', 'dvd@jnu.ac.kr')
